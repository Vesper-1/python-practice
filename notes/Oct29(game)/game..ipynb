# %%
import pygame
pygame.init() #initialization
#Size of the gaming window
screen = pygame.display.set_mode((800,600))
#set window name
pygame.display.set_caption("Move The Square")
#setting the background image
background = pygame.image.load("background_image.jpg")
#define a blue color
BLUE = (0,0,255)
#create the square
player = pygame.Rect(100,100,50,50)
speed_x=3
speed_y=5
clock=pygame.time.clock()

#gmae main loop
running = True
while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    #display the screen
    screen.blit(background,(0,0))
    pygame.display.update
pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.1)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2025-10-29 14:59:54.153 Python[87299:2473199] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-10-29 14:59:54.153 Python[87299:2473199] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 15
#      13 speed_x=3
#      14 speed_y=5
# ---> 15 clock=pygame.time.clock()
#      17 #gmae main loop
#      18 running = True
#
# AttributeError: module 'pygame.time' has no attribute 'clock'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
